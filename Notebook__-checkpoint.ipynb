# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("yair.csv")

# %% [markdown]
# # Comparing netchop predictions to netMHCpan ranks

# %%
df.mean(axis=0)
#all the chopped == true
Chopped_mean = df[df["Chopped"] == True].mean()
#chopped = false
nChoped_mean = df[df["Chopped"] == False].mean()
# Out:
# C:\Users\itayb\AppData\Local\Temp/ipykernel_1464/2619566257.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=0)
# C:\Users\itayb\AppData\Local\Temp/ipykernel_1464/2619566257.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Chopped_mean = df[df["Chopped"] == True].mean()
# C:\Users\itayb\AppData\Local\Temp/ipykernel_1464/2619566257.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nChoped_mean = df[df["Chopped"] == False].mean()

# %% [markdown]
# creating a list of all the mhc supertypes

# %%
mhcpan_df = pd.read_csv("mhc_resualt.csv")
MHC_TYPES = list(set(mhcpan_df["mhc_type"]))
MHC_TYPES = [i + "_rank" for i in MHC_TYPES]
print(MHC_TYPES)
# Out:
# ['HLA-B*40:01_rank', 'HLA-B*39:01_rank', 'HLA-B*15:01_rank', 'HLA-A*02:01_rank', 'HLA-B*07:02_rank', 'HLA-A*24:02_rank', 'HLA-A*01:01_rank', 'HLA-A*03:01_rank', 'HLA-A*26:01_rank', 'HLA-B*08:01_rank', 'HLA-B*27:05_rank', 'HLA-B*58:01_rank']

# %% [markdown]
# Plotting the graph with matplotlib

# %%
labels = MHC_TYPES
chopped_means = Chopped_mean[labels]
nchopped_means = nChoped_mean[labels]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(25)
rects1 = ax.bar(x - width/2, chopped_means, width, label='Predicted to be chopped')
rects2 = ax.bar(x + width/2, nchopped_means, width, label='Not predicted to be chopped')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('NetMHCpan Ranks by netchop predictions')

ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()


plt.show()

# %% [markdown]
# # Comparing netMHCpan ranks to peptides with cystiene

# %%
Cystine_mean = df[df["cysteine"] == True].mean()
NCystine_mean = df[df["cysteine"] == False].mean()
labels = MHC_TYPES
cysteine_means = Cystine_mean[labels]
ncysteine_means = NCystine_mean[labels]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(25)
rects1 = ax.bar(x - width/2, cysteine_means, width, label='Contains cysteine')
rects2 = ax.bar(x + width/2, ncysteine_means, width, label="doesn't contain cysteine")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('NetMHCpan Ranks by cysteine')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()


plt.show()
# Out:
# C:\Users\itayb\AppData\Local\Temp/ipykernel_1464/347764620.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Cystine_mean = df[df["cysteine"] == True].mean()
# C:\Users\itayb\AppData\Local\Temp/ipykernel_1464/347764620.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   NCystine_mean = df[df["cysteine"] == False].mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1464/347764620.py in <module>
#      17 ax.set_ylabel('Scores')
#      18 ax.set_title('NetMHCpan Ranks by cysteine')
# ---> 19 ax.set_xticks(x, labels)
#      20 ax.legend()
#      21
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %% [markdown]
# Creating a a dist graphs for the cysteine and netMHCpan ranks

# %%
import seaborn as sns

Cystine_df = df[df["cysteine"] == True]
cystine_rank1_array = np.array(Cystine_df[MHC_TYPES[0]])

# %%
# Plot
sns.set_style("white")
Cystine_df = df[df["cysteine"] == True]
FCystine_df = df[df["cysteine"] == False]
for i in MHC_TYPES:
    cystine_rank1_array = np.array(Cystine_df[i])    
    fcystine_rank1_array = np.array(FCystine_df[i])
    kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

    plt.figure(figsize=(10,7), dpi= 80)
    xs = sns.distplot(cystine_rank1_array, color="dodgerblue", label="cysteine true")
    sns.distplot(fcystine_rank1_array, color="orange", label="cysteine false")

    plt.xlabel(i.replace("_rank", "") + " ranks")
    plt.legend();
# Out:
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\itayb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
amino_acids = list(set("".join([df["peptide"][i] for i in range(len(df["peptide"]))])))

# %%
Chooped_df = df[df["Chopped"] == True]
NChopped_df = df[df["Chopped"] == False]
chopped_dict = {}
nchopped_dict = {}
for i in Chooped_df["peptide"]:
    last_letter = i[-1]
    if(last_letter not in chopped_dict):
        chopped_dict[last_letter] = 0
    chopped_dict[last_letter] += 1
    
for i in NChopped_df["peptide"]:
    last_letter = i[-1]
    if(last_letter not in nchopped_dict):
        nchopped_dict[last_letter] = 0
    nchopped_dict[last_letter] += 1


number_of_chooped = np.sum(list(chopped_dict.values()))
number_of_unChopped = np.sum(list(nchopped_dict.values()))

# %%
labels = chopped_dict.keys()
chopped_counter = (np.divide(list(chopped_dict.values()), number_of_chooped) * 10000).astype(int) / 100
nchopped_counter = (np.divide(list(nchopped_dict.values()), number_of_unChopped) * 10000).astype(int) / 100

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(25)
fig.set_dpi(200)
rects1 = ax.bar(x - width/2, chopped_counter, width, label='chopped true')
rects2 = ax.bar(x + width/2, nchopped_counter, width, label="chopped false")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Predicted to be chopped by amino acids')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1464/143949150.py in <module>
#      16 ax.set_ylabel('Scores')
#      17 ax.set_title('Predicted to be chopped by amino acids')
# ---> 18 ax.set_xticks(x, labels)
#      19 ax.legend()
#      20
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %% [markdown]
# # BoxPlot

# %%
new_list = []
for mhc_type in MHC_TYPES:
    for i, row in df.iterrows():
        new_list.append([row[mhc_type], row["Chopped"], mhc_type])

cols = ["rank", "chopped", "mhc_type"]
box_df = pd.DataFrame(new_list, columns=cols)

# %%
import seaborn as sns

labels = MHC_TYPES

sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")

sns.set(font_scale = 1.3)
print(box_df.head())
plt.figure(figsize = (30,10))

ax = sns.boxplot(x="mhc_type", y="rank", hue="chopped",
                 data=box_df, palette="Set3")
ax = sns.swarmplot(x="mhc_type", y="rank", hue="chopped",
                 data=box_df, palette="Set3")
plt.legend(loc="upper right", title="chopped")

# %% [markdown]
# # Comapring netMHCpan ranks to peptides with N-Glycolization

# %%
import seaborn as sns
df = pd.read_csv("Nahom.csv")
glyc_df = df[df["Potential"] > 0]
nglyc_df = df[df["Potential"] == 0]
# Plot
sns.set_style("white")

for i in MHC_TYPES:
    glyc_rank1_array = np.array(glyc_df[i])    
    fglyc_rank1_array = np.array(nglyc_df[i])
    kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

    plt.figure(figsize=(10,7), dpi= 80)
    xs = sns.distplot(glyc_rank1_array, color="dodgerblue", label="glyc true")
    sns.distplot(fglyc_rank1_array, color="orange", label="glyc false")

    plt.xlabel(i.replace("_rank", "") + " ranks")
    plt.legend();
